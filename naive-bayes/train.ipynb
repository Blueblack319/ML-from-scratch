# %%
import numpy as np
from sklearn import datasets 
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from model import NaiveBayes

# %%
X, y = datasets.make_classification(n_samples=1000, n_features=10, n_classes=2, random_state=1234)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1234)
# print(y_train[:10])
# figure = plt.figure()
plt.xlabel('x1')
plt.ylabel('x2')
m1 = plt.plot(X_train[y_train == 0, 2], X_train[y_train == 0, 5], 'bx', linewidth=2)
m2 = plt.plot(X_train[y_train == 1, 2], X_train[y_train == 1, 5], 'go', linewidth=2)
plt.show()

# %%
def accuracy(y_true, y_pred):
    return np.sum(y_pred == y_true) / len(y_true)

# %%
model = NaiveBayes()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
acc = accuracy(y_test, y_pred)
print(acc)
# Out:
# 0.925
