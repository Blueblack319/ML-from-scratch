# %%
import numpy as np
from sklearn.datasets import make_blobs
from model import KMeans
np.random.seed(42)
# Out:
# /home/hoon/anaconda3/envs/ml-from-scratch/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
X, y = make_blobs(centers=3, n_samples=500, n_features=2, shuffle=True, random_state=40)
print(X.shape)

clusters = len(np.unique(y))
print(clusters)
# Out:
# (500, 2)
# 3

# %%
k = KMeans(K=clusters, max_iters=150, plot_steps=True)
y_pred = k.predict(X)

k.plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 k = KMeans(K=clusters, max_iters=150, plot_steps=True)
# ----> 2 y_pred = k.predict(X)
#       4 k.plot()
#
# File ~/Documents/ml-from-scratch/K-means/model.py:79, in KMeans.predict(self, X)
#      76     self.plot()
#      78 old_centroids = self.centroids
# ---> 79 self.centroids = self._get_centroids(self.clusters)
#      81 if self._is_converged(old_centroids, self.centroids):
#      82     break
#
# File ~/Documents/ml-from-scratch/K-means/model.py:41, in KMeans._get_centroids(self, clusters)
#      39 for label, cluster in enumerate(clusters):
#      40     cluster_means = np.mean(self.X[cluster], axis=0)
# ---> 41     centroids[label] = cluster_means
#      42 return centroids
#
# ValueError: could not broadcast input array from shape (2,) into shape (500,)
